# %% [markdown]
# Here’s a very brief, correct, PEP-8-aligned summary of Python naming conventions:
#
# - Modules & files: lowercase_with_underscores.py
# - Packages: lowercase (no underscores if possible)
# - Functions: lowercase_with_underscores
# - Variables: lowercase_with_underscores
# - Constants: UPPERCASE_WITH_UNDERSCORES
# - Classes: CamelCase
# - Instance methods: lowercase_with_underscores, first arg should be self
# - Class methods: same as above, first arg should be cls
# - Private/internal: prefix with a single underscore _internal
# - Name-mangling (avoid unless needed): prefix with double underscore __var
