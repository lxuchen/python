# %% [markdown]
# ## Whetting Your Appetite
#
# Why Python?
#
# If you want to automation or you want to proto-type, then Python is for you
# - Python is simple to use. (What is **awk**? should I learn it?)
# - Python has modules
# - Python is interpreted, can be interactive
# - Python is compact:
#     - high-level data types
#     - indentation
#     - no variable declarations
# Python is extensible
